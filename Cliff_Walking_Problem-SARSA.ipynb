# %%
import gymnasium as gym
import numpy as np
import random

# %%
env = gym.make("CliffWalking-v1")

# %%
print(env.observation_space.n) #Number of state
print(env.action_space.n) # number of action

state,_ = env.reset() #36=>12*3+0
print(state) # starting state
# Out:
# 48
# 4
# 36
